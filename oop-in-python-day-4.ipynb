# %% [markdown]
# Polymorphism
# Method Overriding
#
# Method Overloading
#
# Operator Overloading

# %% [markdown]
# Same function/method/operator → different behavior depending on object.
#
# Simple word me:
# Ek hi cheez alag-alag objects ke saath different way me work kare = Polymorphism.

# %% [markdown]
# Think:
#
# Animal.sound()
# Dog → "Bark"
# Cat → "Meow"
#
# Method same = sound()
#
# But output different.
#
# This is polymorphism.

# %%
#mwthod overriding
class Animal:
    def sound(self):
        print("Animal sound")

class Dog(Animal):
    def sound(self):
        print("Bark")

# %% [markdown]
# This is:
#
# Method Overriding
#
# And because same method behaves differently:
#
# It is also Polymorphism

# %%
class Dog:
    def sound(self):
        print("Bark")

class Cat:
    def sound(self):
        print("Meow")

d = Dog()
c = Cat()

d.sound()
c.sound()
# Out:
# Bark
# Meow

# %%
# Method Overriding
class Phone:
    def __init__(self, price, brand, camera):
        print ("Inside phone constructor")
        self.__price = price
        self.brand = brand
        self.camera = camera

    def buy(self):
        print ("Buying a phone")

class SmartPhone(Phone):
    def buy(self):
        print ("Buying a smartphone")

s=SmartPhone(20000, "Apple", 13)

s.buy()
# Out:
# Inside phone constructor
# Buying a smartphone

# %% [markdown]
# Method overriding is an example of runtime polymorphism.
# because runtime pe decide hota hai konsa method chalega.
#
# Example:
#
# a = Dog()
# a.sound()
#
# Runtime pe Python dekhega:
#
# object Dog ka hai
# so Dog ka sound() chalega

# %%
#overloading
#Same method name
#but different number/type of arguments.
class Demo:
    
    def add(self,a,b):
        print(a+b)

    def add(self,a,b,c):
        print(a+b+c)

# %%
class Shape:

  def area(self,a,b=0):
    if b == 0:
      return 3.14*a*a
    else:
      return a*b

s = Shape()

print(s.area(2))
print(s.area(3,4))
# Out:
# 12.56
# 12

# %% [markdown]
# Then How Python Achieves Overloading?
#
# Using:
#
# default arguments
# *args

# %%
#Method Overloading Using Default Arguments
class Demo:

    def add(self,a,b,c=0):
        print(a+b+c)

d = Demo()

d.add(1,2)
d.add(1,2,3)
# Out:
# 3
# 6

# %%
#using args
class Demo:

    def add(self,*nums):
        print(sum(nums))

d = Demo()

d.add(1,2)
d.add(1,2,3)
d.add(1,2,3,4)
# Out:
# 3
# 6
# 10

# %% [markdown]
# Python does not support true method overloading directly, but it can be achieved using default arguments or *args.

# %%
#operator overloading
'hello' + 'world'
# Out:
# 'helloworld'

# %%
25 + 9
# Out:
# 34

# %%
[1,2,3] + [4,5]
# Out:
# [1, 2, 3, 4, 5]
