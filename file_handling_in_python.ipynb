# %% [markdown]
# Types of data used for I/O: Text - '12345' as a sequence of unicode chars
#
# Binary - 12345 as a sequence of bytes of its binary equivalent
#
# Hence there are 2 file types to deal with Text files - All program files are text files Binary Files - Images,music,video,exe files

# %% [markdown]
# add Codeadd Markdown
# arrow_upwardarrow_downwarddelete
# How File I/O is done in most programming languages
#
# Open a file
#
# Read/Write data
#
# Close the file

# %% [markdown]
# writing a file

# %%
# case 1 - if the file is not present
f = open('sample.txt','w')
f.write('Hello world')
f.close()

# %%
# since file is closed hence this will not work
f.write('hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_506/7414254.py in <cell line: 0>()
#       1 # since file is closed hence this will not work
# ----> 2 f.write('hello')
#
# ValueError: I/O operation on closed file.

# %%
# write multiline strings
f = open('sample1.txt','w')
f.write("hii tanishka")
f.write("\n how are you?")
f.close()

# %%
# case 2 - if the file is already present
f=open('sample.txt','w')
f.write("hiii khushi")
f.close()

# %% [markdown]
# If you make changes in an existing file, the old data may be overwritten and the new data will replace it.

# %% [markdown]
# how exactly open() works?
# open()
#    ↓
#
# OS opens file
#    ↓
#
# File handle created
#    ↓
#
# Buffer created in RAM
#    ↓
#
# read/write happens through buffer
#    ↓
#
# close()
#    ↓
#
# Buffer saved to hard drive

# %%
# Problem with w mode
# introducing append mode
f = open('sample.txt','a')
f.write("\n hello khushi! what's up")
f.close()

# %%
# write lines
L = ['hello\n','how\n','are\n','you?\n','I am fine']
f = open('/content/temp sample1.txt','w')
f.writelines(L)
f.close()

# %% [markdown]
# why close the file ? is it compuslory ?
# `close()` ka main reason hai:
#
# 1. Buffer ka data hard drive me properly save karna
#
# When you write:
#
# f.write("Hello")
#
# Data pehle mostly **RAM buffer** me jata hai, directly hard drive me nahi.
# Python → Buffer (RAM) → Hard Drive
# ```
#
# close() bolta hai:
#
# “Jo bhi buffer me pending data hai, sab hard drive me save kr do.”
#  2. File resources free karna
#
# Jab file open hoti hai:
#
# * OS ek file handle use karta hai
# * RAM/resources occupied hote hain
#
# close() ke baad:
# * resources free ho jate hain
# * unnecessary memory usage avoid hota hai
#
#  3. Data corruption avoid karna
#
# Agar program suddenly band ho gaya before close():
#
# f.write("Important data")
#
# toh possible hai:
#
# * buffer ka data save hi na ho
# * file incomplete ho jaye
#
# # Real-life analogy
#
# Imagine:
#
# * Hard drive = notebook
# * Buffer = rough page
#
# Pehle rough page pe likhte ho.
# close() = final notebook me neatly transfer + notebook band.
#
# Best practice
# f = open("data.txt", "w")
# f.write("Hello")
# f.close()
#
#
# OR better:
#
# with open("data.txt", "w") as f:
#     f.write("Hello")
#
# with automatically close() kar deta hai.

# %% [markdown]
# read()
#
#  Reads entire file at once
#
# f = open("data.txt", "r")
# data = f.read()
# What happens:
# Whole file content is loaded into memory (RAM)
# Returns a single string

# %% [markdown]
# readline()
#
# Reads one line at a time
#
# f = open("data.txt", "r")
# line1 = f.readline()
# line2 = f.readline()
# Output:
# "Hello\n"
# "World\n"
#
#  good for large files
# memory efficient
# line-by-line processing

# %% [markdown]
# Feature       	  read()	        readline()
#
# Reads	          Full file	         One line
#
# Return type   	Single string    	Single line string
#
# Memory usage	  High (large files)   	Low
#
# Speed usage	   Fast for small file	  Better for big file

# %%
# reading from files
# -> using read()
f = open('sample.txt','r')
s = f.read()
print(s)
f.close()
# Out:
# hiii khushi
#  hello khushi! what's up

# %%
f = open('sample.txt','r')
s = f.read(16)
print(s)
f.close()
# Out:
# hiii khushi
#  hel

# %% [markdown]
# file me always string form me honga. text..

# %%
#readline
f = open('sample1.txt','r')
print(f.readline())
print(f.readline())
f.close()
# Out:
# hii tanishka
#
#  how are you?

# %%
#readline
f = open('sample1.txt','r')
print(f.readline(),end='')
print(f.readline(),end='')
f.close()
# Out:
# hii tanishka
#  how are you?

# %%
# reading entire using readline
f = open('sample1.txt','r')
while True:
  data = f.readline()
  if data == '':
    break
  else:
    print(data,end='')
# Out:
# hii tanishka
#  how are you?

# %% [markdown]
# Using Context Manager (With)-
# It's a good idea to close a file after usage as it will free up the resources
# If we dont close it, garbage collector would close it
# with keyword closes the file as soon as the usage is over

# %%
# with
with open('sample1.txt','w') as f:
  f.write('but why?')

# %%
f.write('jfk')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_506/3824905373.py in <cell line: 0>()
# ----> 1 f.write('jfk')
#
# ValueError: I/O operation on closed file.

# %%
# try f.read() now
with open('sample.txt','r') as f:
  print(f.readline())
# Out:
# hiii khushi

# %%
# try f.read() now
with open('sample.txt','r') as f:
    print(f.read())
# Out:
# hiii khushi
#  hello khushi! what's up

# %%
# moving within a file - 10 char then 10 char

with open('sample.txt','r')as f:
  print(f.read(10))
  print(f.read(10))
# Out:
# hiii khush
# i
#  hello k

# %%
# benefit? -> to load a big file in memory
big_L = ['hello world ' for i in range(1000)]

with open('big.txt','w') as f:
  f.writelines(big_L)

# %%
with open('big.txt','r') as f:
  chunk_size = 10
  while len (f.read(chunk_size)) > 0:
    print(f.read(chunk_size),end='***')
    f.read(chunk_size)
# Out:
# d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo***o world he***d hello wo
# ...

# %%
#seek and tail function
#f.tail is a mechanism which is used to tell how much mechanism in program is run and how much program is left. currently where is my cursor. cursor point show
#f.seek used to reset the cursor position
#f.tail() Returns the current position of the file pointer (in bytes).
#f.seek() Moves the file pointer to a specific position.
with open('sample.txt','r') as f:
  print(f.read(10))
  print(f.tell())
  f.seek(15)
  print(f.read(10))
  print(f.tell())
# Out:
# hiii khush
# 10
# llo khushi
# 25

# %%
# seek during write
with open('sample.txt','w') as f:
  f.write('Hello')
  f.seek(0)
  f.write('Xa')

# %% [markdown]
# Problems with working in text mode
# can't work with binary files like images
# not good for other data types like int/float/list/tuples

# %%
# working with binary file
with open('/content/Screenshot 2026-05-20 141359.png','r') as f:
  f.read()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipykernel_506/3625961988.py in <cell line: 0>()
#       1 # working with binary file
#       2 with open('/content/Screenshot 2026-05-20 141359.png','r') as f:
# ----> 3   f.read()
#
# /usr/lib/python3.12/codecs.py in decode(self, input, final)
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x89 in position 0: invalid start byte

# %%
# working with binary file
with open('/content/Screenshot 2026-05-20 141359.png','rb') as f:
  with open('/content/Screenshot 2026-05-20 141359.png','wb') as wf:
    wf.write(f.read())

# %% [markdown]
# text data me main problem is that it work only for string datatype. not integer ..

# %%
# working with a big binary file

# %%
# working with other data types
with open('sample.txt','w') as f:
  f.write(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_506/501816704.py in <cell line: 0>()
#       1 # working with other data types
#       2 with open('sample.txt','w') as f:
# ----> 3   f.write(5)
#
# TypeError: write() argument must be str, not int

# %%
with open('sample.txt','w') as f:
  f.write('5')

# %%
with open('sample.txt','r') as f:
  print(int(f.read()) + 5)
# Out:
# 10

# %%
# more complex data
d = {
    'name':'nitish',
     'age':33,
     'gender':'male'
}

with open('sample.txt','w') as f:
  f.write((d))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_506/1347705437.py in <cell line: 0>()
#       7
#       8 with open('sample.txt','w') as f:
# ----> 9   f.write((d))
#
# TypeError: write() argument must be str, not dict

# %%
# more complex data
d = {
    'name':'tanishka',
     'age':19,
     'gender':'female'
}

with open('sample.txt','w') as f:
  f.write(str(d))

# %%
with open('sample.txt','r') as f:
  print(dict(f.read()))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_506/2317878920.py in <cell line: 0>()
#       1 with open('sample.txt','r') as f:
# ----> 2   print(dict(f.read()))
#
# ValueError: dictionary update sequence element #0 has length 1; 2 is required

# %% [markdown]
# string se dict again type conversion not possible , this is the big problem . sol - serialization and deserialization.

# %% [markdown]
# Serialization - process of converting python data types to JSON format
# Deserialization - process of converting JSON to python data types

# %%
# serialization using json module
# list
import json

L = [1,2,3,4]

with open('demo.json','w') as f:
  json.dump(L,f)

# %%
# dict
d = {
    'name':'tanishka',
     'age':19,
     'gender':'female'
}

with open('demo.json','w') as f:
  json.dump(d,f,indent=4)

# %%
#deserialization
import json
with open('demo.json','r') as f:
  print(json.load(f))
# Out:
# {'name': 'tanishka', 'age': 19, 'gender': 'female'}

# %%
import json
with open('demo.json','r') as f:

  d = json.load(f)
  print(d)
  print(type(d))
# Out:
# {'name': 'tanishka', 'age': 19, 'gender': 'female'}
# <class 'dict'>

# %%
# serialize and deserialize tuple
import json

t = (1,2,3,4,5)

with open('demo.json','w') as f:
  json.dump(t,f)

# %% [markdown]
# but why ?? in serialize and deserialize tuple in both we are getting same result list ?

# %%
# serialize and deserialize a nested dict

d = {
    'student':'Tanishka',
     'marks':[99,94,84,95,96]
}

with open('demo.json','w') as f:
  json.dump(d,f)

# %% [markdown]
# Serializing and Deserializing custom objects

# %%
class Person:
  def __init__(self,fname,lname,age,gender):
    self.fname = fname
    self.lname = lname
    self.age = age
    self.gender = gender

    # format to printed in
# Tanishka Golya age -> 19 gender -> female

# %%
person = Person("Tanishka"," Golya",19,"female")

# %%
import json
with open("demo.json",'w') as f:
  json.dump(person,f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_506/2287292413.py in <cell line: 0>()
#       1 import json
#       2 with open("demo.json",'w') as f:
# ----> 3   json.dump(person,f)
#
# /usr/lib/python3.12/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# /usr/lib/python3.12/json/encoder.py in _iterencode(o, _current_indent_level)
#     437                     raise ValueError("Circular reference detected")
#     438                 markers[markerid] = o
# --> 439             o = _default(o)
#     440             yield from _iterencode(o, _current_indent_level)
# ...

# %%
# As a string
import json

def show_object(person):
  if isinstance(person,Person):
    return "{} {} age -> {} gender -> {}".format(person.fname,person.lname,person.age,person.gender)

with open('demo.json','w') as f:
  json.dump(person,f,default=show_object)

# %%
# As a dict
import json

def show_object(person):
  if isinstance(person,Person):
    return {'name':person.fname + ' ' + person.lname,'age':person.age,'gender':person.gender}

with open('demo.json','w') as f:
  json.dump(person,f,default=show_object,indent=4)

# %%
# deserializing
import json

with open('demo.json','r') as f:
  d = json.load(f)
  print(d)
  print(type(d))
# Out:
# {'name': 'Tanishka  Golya', 'age': 19, 'gender': 'female'}
# <class 'dict'>

# %% [markdown]
# Pickling
# Pickling is the process whereby a Python object hierarchy is converted into a byte stream, and unpickling is the inverse operation, whereby a byte stream (from a binary file or bytes-like object) is converted back into an object hierarchy.

# %%
class Person:

  def __init__(self,name,age):
    self.name = name
    self.age = age

  def display_info(self):
    print('Hi my name is',self.name,'and I am ',self.age,'years old')

# %%
p = Person('tanishka',19)

# %%
# pickle dump
import pickle
with open('person.pkl','wb') as f:
  pickle.dump(p,f)

# %%
# pickle load
import pickle
with open('person.pkl','rb') as f:
  p = pickle.load(f)

p.display_info()
# Out:
# Hi my name is tanishka and I am  19 years old

# %% [markdown]
# Pickle Vs Json
# Pickle lets the user to store data in binary format. JSON lets the user store data in a human-readable text format.
