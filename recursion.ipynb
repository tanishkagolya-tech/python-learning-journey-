# %%
def multiply(a,b):
    result=0
    for i in range(b):
        result=result+a
    print(result)
multiply(3,4)
# Out:
# 12

# %%
def mul(a,b):
    if b == 1:
        return a
    else:
        return a+mul(a,b-1)
print(mul(5,4))
# Out:
# 20

# %%
#factorial 
def fact(number):
    if number == 1:
        return 1
    else:
        return number*fact(number-1)
print(fact(5))
# Out:
# 120

# %%
#palindrome 
def palin(text):
    if len(text) <= 1:
        print("Palindrome")
    else:
        if text[0] == text[-1]:
            palin(text[1:-1])
        else:
            print("Not Palindrome")
palin("madam")
palin("hk")
palin("neha")
palin("rgfgf")
# Out:
# Palindrome
# Not Palindrome
# Not Palindrome
# Not Palindrome

# %%
#rabbit problem
def fib(m):
    if m==0 or m==1:
        return 1
    else:
        return fib(m-1) + fib(m-2)
print(fib(12))
#but in this case because of tree,repeatation, time increases..how can we reduce time??increase space...reduce time. it is called space time trade off (dynamic programming)
# Out:
# 233

# %%
import time 
def memo(m,d):
    if m in d:
        return d[m]
    else:
        d[m]=memo(m-1,d)+memo(m-2,d)
        return d[m]
start =time.time()
d={0:1,1:1}
print(memo(500,d))
print(time.time()-start)
# Out:
# 225591516161936330872512695036072072046011324913758190588638866418474627738686883405015987052796968498626
# 0.0005488395690917969
